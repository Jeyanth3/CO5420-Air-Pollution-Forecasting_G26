# %% [markdown]
# # RMSE Improvement And Error Analysis
#
# This notebook runs the compact LightGBM improvement workflow, performs official-test diagnostic error analysis, and writes the improved submission candidate.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT))
ROOT

# %%
from src.rmse_improvement_error_analysis import run

run(data_dir=ROOT / 'data' / 'raw', output_dir=ROOT, train_fraction=0.8, random_state=42)

# %%
import pandas as pd

report_dir = ROOT / 'reports' / 'rmse_improvement_error_analysis'
pd.read_csv(report_dir / 'model_results.csv')

# %%
pd.read_csv(report_dir / 'band_metrics.csv').head(20)

# %%
pd.read_csv(report_dir / 'station_metrics.csv').sort_values('rmse', ascending=False).head(15)
