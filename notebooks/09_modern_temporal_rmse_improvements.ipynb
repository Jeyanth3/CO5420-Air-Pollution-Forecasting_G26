# %% [markdown]
# # Modern Temporal RMSE Improvements
#
# This notebook compares compact LightGBM, station-specific LightGBM, XGBoost, CatBoost, diagnostic blending, and a neural feasibility result against the official-data diagnostic target.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT))
ROOT

# %%
from src.modern_temporal_rmse_improvements import run

run(data_dir=ROOT / 'data' / 'raw', output_dir=ROOT, train_fraction=0.8, random_state=42)

# %%
import pandas as pd

report_dir = ROOT / 'reports' / 'modern_temporal_rmse_improvements'
pd.read_csv(report_dir / 'model_results.csv')

# %%
pd.read_csv(report_dir / 'band_metrics.csv').head(20)

# %%
pd.read_csv(report_dir / 'station_metrics.csv').sort_values('rmse', ascending=False).head(15)
