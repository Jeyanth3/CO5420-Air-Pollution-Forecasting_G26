# %% [markdown]
# # Final Objective Experiments And Official Submissions
#
# This notebook runs Objective 1-6 on the final official Kaggle files, generates validation/error-analysis tables, and writes two official submission candidates.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT))
ROOT

# %%
from src.final_objective_experiments import run

run(data_dir=ROOT / 'data' / 'raw', output_dir=ROOT, train_fraction=0.8, max_boost_train_rows=180_000, random_state=42)

# %%
import pandas as pd

report_dir = ROOT / 'reports' / 'final_objective_experiments'
pd.read_csv(report_dir / 'experiment_summary.csv')

# %%
pd.read_csv(report_dir / 'model_results.csv').head(12)

# %%
pd.read_csv(report_dir / 'objective_status.csv')
