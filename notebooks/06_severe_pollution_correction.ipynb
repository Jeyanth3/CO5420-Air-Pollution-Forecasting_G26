# %% [markdown]
# # Severe-Pollution Correction
#
# This notebook runs targeted experiments for the largest error mode found in the previous analysis: underprediction when true PM2.5 is above 150.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT))
ROOT

# %%
from src.severe_pollution_correction import run

run(data_dir=ROOT / 'data' / 'raw', output_dir=ROOT, train_fraction=0.8, max_boost_train_rows=180_000, random_state=42)

# %%
import pandas as pd

report_dir = ROOT / 'reports' / 'severe_pollution_correction'
pd.read_csv(report_dir / 'experiment_summary.csv')

# %%
pd.read_csv(report_dir / 'model_results.csv').head(12)

# %%
pd.read_csv(report_dir / 'band_metrics.csv').query("pm25_band == 'severe_>150'").sort_values('rmse').head(12)
