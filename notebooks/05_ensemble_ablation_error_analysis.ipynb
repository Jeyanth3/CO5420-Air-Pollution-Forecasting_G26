# %% [markdown]
# # Ensemble, Ablation, and Error Analysis
#
# This notebook runs the final analysis layer over the saved validation predictions from the baseline, boosting, and temporal neural model stages. It builds ensemble candidates, evaluates feature/imputation ablations, and creates station-wise and PM2.5-band error plots.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT))
ROOT

# %%
from src.ensemble_ablation_error_analysis import run

run(data_dir=ROOT / 'data' / 'raw', output_dir=ROOT, train_fraction=0.8, blend_train_fraction=0.5)

# %%
import pandas as pd

report_dir = ROOT / 'reports' / 'ensemble_ablation_error_analysis'
pd.read_csv(report_dir / 'analysis_summary.csv')

# %%
pd.read_csv(report_dir / 'ensemble_results.csv').head(10)

# %%
pd.read_csv(report_dir / 'ablation_results.csv')
